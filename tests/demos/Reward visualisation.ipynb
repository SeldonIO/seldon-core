# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import pandas as pd

# %%
N = 1000
p = np.random.normal(size=N).cumsum()
p[500:] += 40.
p -= p.min()
p /= p.max()
r = np.random.random(size=N)<p

# %%
plt.plot(p)

# %%
plt.plot(r)

# %%
span = 50
r_ewm = pd.Series(r).ewm(span=span).mean()
r_rollmean = pd.Series(r).rolling(window=span).mean()

plt.plot(p)
plt.plot(r_ewm)
plt.plot(r_rollmean)

# %%
N = 1000
p = np.random.normal(size=N).cumsum()
p[500:] += 100.
p -= p.min()
p /= p.max()
r = np.random.normal(p,0.2,size=N)

# %%
plt.plot(p)

# %%
plt.plot(r)

# %%
span = 50
r_ewm = pd.Series(r).ewm(span=span).mean()
r_rollmean = pd.Series(r).rolling(window=span).mean()

plt.plot(p)
plt.plot(r_ewm)
plt.plot(r_rollmean)
